# %%
import torch
import pandas as pd
import numpy as np

train_data_file = "Brunel_BdJPsiKs_MagU_30k.csv"
data = pd.read_csv(train_data_file)
features = data.drop(["is_true_seed","has_MCParticle",
                      "is_downstream_reconstructible",
                      "has_MCParticle_not_electron",
                     "is_downstream_reconstructible_not_electron",
                     "seed_mva_value"] , axis=1).astype(np.float64)

target = data.is_downstream_reconstructible
features = features.drop(features.columns[0], axis=1)

print(features.head(20))
# Out:
#     seed_chi2PerDoF        seed_p      seed_pt  seed_nLHCbIDs  seed_nbIT  \
# 0          1.447929   1849.101146  1083.522737           27.0        0.0
# 1          0.354945  10085.622823  1345.148537           24.0        0.0
# 2          2.906524   2441.534682  1013.888408           24.0        0.0
# 3          3.234916   2604.073941   904.097232           24.0        0.0
# 4          0.842265   2644.554049  1068.602364           23.0        0.0
# 5          1.006955   2192.137688  1073.852847           23.0        0.0
# 6          1.072540   2665.828607  1207.615135           23.0        0.0
# 7          1.910106   1982.185052  1098.496848           23.0        0.0
# 8          1.378484   3299.094845  1225.976276           22.0        0.0
# 9          1.879188   7168.990553  1161.375854           18.0        0.0
# 10         3.885850   6557.645783  1297.828111           18.0        0.0
# 11         1.242752   2030.790067  1101.790237           25.0        0.0
# ...

# %%
print(target.head(10))
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# 5     True
# 6     True
# 7    False
# 8     True
# 9     True
# Name: is_downstream_reconstructible, dtype: bool
# 1849.10114582

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
features.hist(column='seed_chi2PerDoF',bins=200)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001932579D9B0>]],
#       dtype=object)

# %%
features.hist(column='seed_p',bins = 200, range = [0,50000])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000019325BA0EB8>]],
#       dtype=object)

# %%
features.hist(column='seed_pt', bins = 200, range = [0, 3000])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000019325C00E48>]],
#       dtype=object)

# %%
features.hist(column='seed_nLHCbIDs', bins = 25)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000019326189588>]],
#       dtype=object)

# %%
features.hist(column='seed_nbIT', bins = 50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000193261E8A90>]],
#       dtype=object)

# %%
features.hist(column='seed_nLayers', bins = 50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000019326511080>]],
#       dtype=object)

# %%
features.hist(column='seed_x', bins = 200)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000193264BE588>]],
#       dtype=object)

# %%
features.hist(column='seed_y', bins = 200)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000193263DC0F0>]],
#       dtype=object)

# %%
features.hist(column='seed_tx', bins = 200)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001932689FD68>]],
#       dtype=object)

# %%
features.hist(column='seed_ty', bins = 200)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001932556AD30>]],
#       dtype=object)

# %%
corr = features.corr()
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(features.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(features.columns)
ax.set_yticklabels(features.columns)
plt.show()
